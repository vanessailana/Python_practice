# %%
num=int(input('enter a number'));

#factors of that number
a=[x for x in range(2,num) if num % x ==0]

print(a)


def prime(a):
    
    if num > 1:
        if len(a)==0:
        
            print "prime"
    
    else:
        print "not prime"
        


        
        
        
        
prime(a)
# Out:
# enter a number1
# []
# not prime
