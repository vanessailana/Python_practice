# %%
string=raw_input("Enter string:")
if(string==string[::-1]):
      print("palindrome")
else:
      print("no")
# Out:
# Enter string:aa
# palindrome

# %%
string='hi'

if(string == string[::-1]):
    print "hi"
else:
    print"hno"
# Out:
# hno

# %%
string= 'ab'

if(string == string[::-1]):
    print "pali"
else:
    print "nao"
# Out:
# nao
